# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.12.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, huggingface-hub, datasets
# Successfully installed datasets-2.14.5 dill-0.3.7 huggingface-hub-0.18.0 multiprocess-0.70.15 xxhash-3.4.1

# %%
from gensim.models import Word2Vec
import pandas as pd
import re
from gensim.parsing.preprocessing import strip_punctuation, strip_numeric, strip_short, stem_text
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
from datasets import load_dataset

dataset_corpus = load_dataset("large_spanish_corpus", "ParaCrawl")
# Out:
# Downloading builder script:   0%|          | 0.00/3.93k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.26k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.79G [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/15510649 [00:00<?, ? examples/s]

# %%
dataset_corpus
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 15510649
#     })
# })

# %%
subset = dataset_corpus['train'].select(range(1000000))

# %%
subset[0, 2]
# Out:
# {'text': ['lavado de cerebro a través de los medios de comunicación, y amenaza de fuerza a través de los militares.',
#   'En realidad, el Nuevo OM sólo se puede mantener la ilusión de supremacía mágica, siempre y cuando reprima y desvíe el potencial humano, donde mora la verdadera magia: es decir, en la capacidad innata de nuestra especie de magia interactiva con los poderes de animación de la diosa planetaria.']}

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### Procesamiento de texto

# %%
def clean_text(sentence_batch):
  # extraemos el texto de la entrada
  text_list = sentence_batch['text']

  cleaned_text_list = []

  for text in text_list:
    # convertir el texto a minuscula
    text = text.lower()

    # Eliminar URLs
    text = re.sub(r"http\S+", "", text)

    # Eliminar las menciones @ y '#' de las redes sociales
    text = re.sub(r"@\S+", "", text)
    text = re.sub(r"#\S+", "", text)

    # Eliminar los caracteres de puntuación

    text = strip_punctuation(text)

    # Eliminar números
    text = strip_numeric(text)

    # Eliminar las palabras cortas

    text = strip_short(text, minsize=2)

    # Eliminar las palabras comunes (stop words)

    stop_words = set(stopwords.words('spanish'))
    word_token = word_tokenize(text)
    filtered_text = [word for word in word_token if word not in stop_words]

    cleaned_text_list.append(filtered_text)

  # devuelve el texto limpio
  return {'text': cleaned_text_list}

# %%
sentences_corpus = subset.map(clean_text, batched=True)
# Out:
# Parameter 'function'=<function clean_text at 0x78517e8ae560> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# WARNING:datasets.fingerprint:Parameter 'function'=<function clean_text at 0x78517e8ae560> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Map:   0%|          | 0/1000000 [00:00<?, ? examples/s]

# %%
sentences_corpus['text']
# Out:
# [['lavado',
#   'cerebro',
#   'través',
#   'medios',
#   'comunicación',
#   'amenaza',
#   'fuerza',
#   'través',
#   'militares'],
#  ['constante',
#   'aluvión',
#   'doble',
#   'cañón',
#   'requiriendo',
#   'complicidad',
#   'seres',
#   'humanos',
#   'reprimir',
#   'engañar',
#   'semejantes',
#   'tan',
#   'cacareada',
#   'magia',
#   'rápidamente',
#   'desvanecería',
#   'disiparía'],
#  ['realidad',
#   'nuevo',
#   'om',
#   'sólo',
#   'puede',
#   'mantener',
#   'ilusión',
#   'supremacía',
#   'mágica',
#   'siempre',
#   'reprima',
#   'desvíe',
#   'potencial',
#   'humano',
#   'mora',
#   'verdadera',
#   'magia',
#   'decir',
#   'capacidad',
#   'innata',
#   'especie',
#   'magia',
#   'interactiva',
#   'poderes',
#   'animación',
#   'diosa',
#   'planetaria'],
#  ['menos',
#   'nuevo',
#   'om',
#   'pueda',
#   'tiempo',
#   'suprimir',
#   'capacidad',
#   'manera',
#   'brutal',
#   'natural',
#   'espontáneamente',
#   'afirmará',
#   'misma'],
#  ['haga',
#   'verdadera',
#   'magia',
#   'anthropos',
#   'niño',
#   'luminoso',
#   'entrará',
#   'inmediato',
#   'acción'],
#  ['sophia',
#   'misma',
#   'desea',
#   'humanidad',
#   'dueña',
#   'habilite',
#   'verdadero',
#   'potencial',
#   'magia',
#   'utilice',
#   'derrotar',
#   'arcontes',
#   'desterrarlos',
#   'propio',
#   'dominio',
#   'pozo',
#   'gravedad',
#   'abismo',
#   'sistema',
#   'planetario',
#   'inanimado'],
#  ['términos',
#   'geofísicos',
#   'fuerza',
#   'gravedad',
#   'inherente',
#   'leyes',
#   'bioenergéticas',
#   'planeta',
#   'viviente',
#   'permite',
#   'arcontes',
#   'colonizar',
#   'complejo',
#   'manipular',
#   'así',
#   'comportamiento',
#   'humano',
#   'mediante',
#   'exageración',
#   'patrones',
#   'rígidos',
#   'habituales',
#   'cerebro',
#   'reptiliano'],
#  ['repito',
#   'repetición',
#   'hace',
#   'evidente',
#   'números',
#   'símbolos',
#   'códigos',
#   'prueba',
#   'genuina',
#   'habilidad',
#   'mágica',
#   'sino',
#   'simplemente',
#   'compulsión',
#   'repetición',
#   'marca',
#   'área',
#   'reptil',
#   'cerebro',
#   'repetición',
#   'reptil'],
#  ['funciones',
#   'complejo',
#   'valor',
#   'limitado',
#   'supervivencia',
#   'exagerado',
#   'actúa',
#   'supervivencia',
#   'hacer',
#   'cumplir',
#   'permite',
#   'poderes',
#   'arcónticos',
#   'desviar',
#   'impulsos',
#   'humanos',
#   'red',
#   'comportamiento',
#   'esclavitud',
#   'robótica'],
#  ['desviación',
#   'robótica',
#   'esencia',
#   'influencia',
#   'arcóntica',
#   'debe',
#   'original',
#   'parte',
#   'parásitos',
#   'alienígenas',
#   'sino',
#   'simplemente',
#   'exageración',
#   'tendencias',
#   'preexistentes',
#   'estructura',
#   'psicosomática',
#   'humanidad',
#   'plasmata',
#   'forma',
#   'modelada',
#   'anthropos'],
#  ['términos',
#   'físicos',
#   'arcontes',
#   'disfrutan',
#   'toma',
#   'funciones',
#   'cerebro',
#   'posterior',
#   'tierra',
#   'capturada',
#   'pozo',
#   'gravedad',
#   'sistema',
#   'solar'],
#  ['consecuencia',
#   'objetos',
#   'tierra',
#   'parecen',
#   'caer',
#   'misma',
#   'tasa',
#   'importar',
#   'tamaño'],
#  ['mito',
#   'erróneo',
#   'ciencia',
#   'dice',
#   'galileo',
#   'demostró',
#   'fenómeno',
#   'dejando',
#   'caer',
#   'dos',
#   'objetos',
#   'pesos',
#   'diferentes',
#   'torre',
#   'inclinada',
#   'pisa'],
#  ['bonito', 'cuento', 'hadas', 'mejor', 'casos'],
#  ['experimento', 'pudo', 'nunca', 'haber', 'ocurrido'],
#  ['cualquier',
#   'caso',
#   'puede',
#   'ser',
#   'repetido',
#   'resultado',
#   'bastante',
#   'diferente'],
#  ['estrecha',
#   'observación',
#   'claro',
#   'objetos',
#   'diferente',
#   'peso',
#   'masa',
#   'objetos',
#   'cargados',
#   'campo',
#   'magnético',
#   'caen',
#   'misma',
#   'tasa',
#   'uniforme'],
#  ['afirmación',
#   'caída',
#   'uniforme',
#   'objetos',
#   'independientemente',
#   'peso',
#   'tamaño',
#   'masa',
#   'falsa',
#   'efecto',
#   'especial',
#   'arcóntico',
#   'convertido',
#   'dogma',
#   'establecido',
#   'ciencia'],
#  ['dogmático', 'engaño'],
#  ['ciencia',
#   'establecida',
#   'enseña',
#   'objetos',
#   'caída',
#   'libre',
#   'demuestran',
#   'aceleración',
#   'gravedad',
#   'caen',
#   'velocidad',
#   'creciente',
#   'ganando',
#   'velocidad',
#   'tasa',
#   'pies',
#   'segundo'],
#  ['aumento',
#   'velocidad',
#   'caída',
#   'libre',
#   'planteada',
#   'ley',
#   'universal',
#   'física',
#   'si',
#   'pudiera',
#   'ser',
#   'manera',
#   'cosmos'],
#  ['cierto', 'efecto', 'detectable', 'aceleración', 'objetos', 'caída'],
#  ['puede', 'ser', 'observado', 'medido', '¿cuál', 'realmente', 'causa'],
#  ['¿es', 'realmente', 'universal', 'invariable', 'supone'],
#  ['aceleración', 'gravedad', 'repetición', 'ciega', 'efecto', 'mecánico'],
#  ['velocidad',
#   'caída',
#   'libre',
#   'incrementa',
#   'cada',
#   'segundo',
#   'misma',
#   'infinitamente',
#   'repetida',
#   'cantidad',
#   'metros',
#   'segundo'],
#  ['puede',
#   'imaginar',
#   'diferente',
#   'cosas',
#   'operación',
#   'diferente',
#   'leyes',
#   'físicas',
#   'cada',
#   'objeto',
#   'comenzaría',
#   'acelerar',
#   'contrario',
#   'quedaría',
#   'suspendido',
#   'espacio',
#   'cayera',
#   'absoluto',
#   'luego',
#   'alcanzaría',
#   'único',
#   'límite',
#   'velocidad',
#   'descenso',
#   'función',
#   'masa',
#   'relativo',
#   'tierra'],
#  ['palabras',
#   'conjunto',
#   'leyes',
#   'físicas',
#   'objetos',
#   'caerían',
#   'tierra',
#   'velocidad',
#   'constante',
#   'aceleración',
#   'determinada',
#   'únicamente',
#   'relación',
#   'masa',
#   'objeto',
#   'específico',
#   'masa',
#   'tierra'],
#  ['así',
#   'podría',
#   'suceder',
#   'caída',
#   'libre',
#   'si',
#   'tierra',
#   'viviente',
#   'capturada',
#   'pozo',
#   'gravitatorio',
#   'planetas',
#   'inorgánicos'],
#  ['conclusión', 'perspectiva', 'gnóstica'],
#  ['aceleración',
#   'gravedad',
#   'insinuado',
#   'efecto',
#   'fantasma',
#   'sistema',
#   'planetario',
#   'arcóntico',
#   'viviente',
#   'dinámica',
#   'tierra',
#   'propiedad',
#   'inherente',
#   'tierra',
#   'sistema',
#   'tres',
#   'cuerpos'],
#  ['mismo',
#   'efecto',
#   'actúa',
#   'cuerpo',
#   'humano',
#   'permite',
#   'parásitos',
#   'arcónticos',
#   'mente',
#   'confisquen',
#   'congelen',
#   'funciones',
#   'instintivas',
#   'complejo'],
#  ['consecuencia',
#   'arcontes',
#   'agarran',
#   'parte',
#   'cuello',
#   'cosquilleo',
#   'sujeto',
#   'mirada',
#   'constante',
#   'atrás'],
#  ['realmente',
#   'alcanzan',
#   'control',
#   'comportamiento',
#   'humano',
#   'manera',
#   'simultáneamente',
#   'congelan',
#   'bloquean',
#   'percepción',
#   'humana',
#   'través',
#   'tipo',
#   'influencia',
#   'parálisis',
#   'ejercen',
#   'campo',
#   'visión',
#   'periférica',
#   'frontalmente'],
#  ['hacen', 'ir', 'venir', 'dice', 'vieja', 'expresión'],
#  ['origen',
#   'mundo',
#   'informa',
#   'derrota',
#   'arcontes',
#   'asunto',
#   'última',
#   'hora',
#   'depende',
#   'alcance',
#   'toda',
#   'extensión',
#   'poderes',
#   'fantasmas',
#   'humanidad'],
#  ['resultado', 'depende', 'intervención', 'humanidad', 'último', 'momento'],
#  ['mito', 'indica', 'claramente', 'drástico', 'repentino', 'giro'],
#  ['niño',
#   'inmortal',
#   'luminoso',
#   'anthropos',
#   'entró',
#   'existencia',
#   'aparecerá',
#   'formas',
#   'modelados',
#   'plasmata'],
#  ['lugar',
#   'moldear',
#   'humanidad',
#   'imagen',
#   'arcontes',
#   'reducidos',
#   'pulpa',
#   'igual',
#   'descarte',
#   'extractor',
#   'jugos'],
#  ['abril',
#   'pueblo',
#   'blanco',
#   'gaucín',
#   'atardecer',
#   'observé',
#   'formación',
#   'nubes',
#   'cielo',
#   'foto',
#   'arriba'],
#  ['sol',
#   'puesto',
#   'detrás',
#   'hacho',
#   'tejados',
#   'ciudad',
#   'flotaba',
#   'figura',
#   'recordó',
#   'vívidamente',
#   'imagen',
#   'arconte',
#   'diseñado',
#   'primeros',
#   'días',
#   'sitio'],
#  ['parecido',
#   'notable',
#   'especialmente',
#   'primer',
#   'momento',
#   'observé',
#   'larga',
#   'formación',
#   'nubes',
#   'horizontales',
#   'darme',
#   'cuenta',
#   'podía',
#   'fotografiar',
#   'teléfono',
#   'celular'],
#  ['período',
#   'media',
#   'hora',
#   'vi',
#   'cabeza',
#   'criatura',
#   'transformarse',
#   'cráneo',
#   'tipo',
#   'et',
#   'apariencia',
#   'perro',
#   'mono'],
#  ['asumió', 'cabeza', 'perro', 'mono'],
#  ['obsesionado', 'aparición', 'cielo', 'pueblo', 'postal', 'andalucía'],
#  ['metió', 'presagio'],
#  ['releer',
#   'texto',
#   'citado',
#   'pude',
#   'ver',
#   'presagio',
#   'tal',
#   'vez',
#   'indicando'],
#  ['momento',
#   'revelación',
#   'poderes',
#   'arcónticos',
#   'alcanzan',
#   'toda',
#   'extensión',
#   'completa',
#   'poderes'],
#  ['momento', 'verdadera', 'forma', 'autoridades', 'fin', 'revelada'],
#  ['presencia',
#   'tierra',
#   'poderes',
#   'fantasma',
#   'operando',
#   'través',
#   'sustitutos',
#   'humanos',
#   'expuestos',
#   'vean'],
#  ['típica',
#   'imagen',
#   'hollywood',
#   'invasión',
#   'alienígena',
#   'hostil',
#   'parte',
#   'naves',
#   'aéreas',
#   'extraterrestres',
#   'alta',
#   'tecnología'],
#  ['combinación', 'anteriores'],
#  ['visión',
#   'gnóstica',
#   'divulgación',
#   'revelación',
#   'momento',
#   'autoridades',
#   'gubernamentales',
#   'anuncian',
#   'presencia',
#   'extraterrestres',
#   'tierra',
#   'haciéndolo',
#   'así',
#   'oficial'],
#  ['hecho',
#   'oficial',
#   'mundo',
#   'cuenta',
#   'táctica',
#   'engaño',
#   'globalista',
#   'avanzando',
#   'agenda',
#   'autoridades'],
#  ['embargo',
#   'arcontes',
#   'hagan',
#   'movimiento',
#   'final',
#   'deberán',
#   'revelarse'],
#  ['debido', 'naturaleza', 'engaño', 'harán', 'forma', 'engañosa'],
#  ['incluso',
#   'mostrar',
#   'presencia',
#   'jugando',
#   'carta',
#   'triunfo',
#   'especie',
#   'humana',
#   'van',
#   'engañar',
#   'hacen',
#   'pueden',
#   'hacer'],
#  ['prueba',
#   'momento',
#   'cae',
#   'humanidad',
#   'ver',
#   'cómo',
#   'autoridades',
#   'estafando',
#   'mundo',
#   'magia',
#   'engañosa',
#   'control',
#   'mente',
#   'tan',
#   'cacareada',
#   'operaciones',
#   'psicológicas',
#   'globales'],
#  ['sophia',
#   'intención',
#   'humanidad',
#   'oportunidad',
#   'llevar',
#   'cabo',
#   'experimento',
#   'divino',
#   'pensó',
#   'originalmente',
#   'libre',
#   'desviación',
#   'arcóntica',
#   'decir',
#   'libre',
#   'falsa',
#   'coerción',
#   'autoridades',
#   'afirman',
#   'agenda',
#   'dominación',
#   'asegura',
#   'seguridad',
#   'social',
#   'libertad',
#   'caos',
#   'moral'],
#  ['tipo', 'libertad', 'realmente', 'esclavitud'],
#  ['términos',
#   'sophiánicos',
#   'libertad',
#   'verdadera',
#   'anarquía',
#   'vida',
#   'tierra',
#   'distingue',
#   'falsa',
#   'amenaza',
#   'caos',
#   'social',
#   'ideado',
#   'autoridades'],
#  ['¿qué',
#   'medidas',
#   'definitivas',
#   'requeridas',
#   'juego',
#   'final',
#   'arcóntico'],
#  ['¿hasta', 'dónde', 'llegará', 'consumación', 'obras', 'señor', 'arconte'],
#  ['momento',
#   'crucial',
#   'venga',
#   'humanidad',
#   'tal',
#   'vez',
#   'capaz',
#   'utilizar',
#   'guerra',
#   'psicológica',
#   'misma',
#   'inter',
#   'especie',
#   'depredadores'],
#  ['liquidarlos', 'propias', 'tácticas'],
#  ['podría',
#   'ser',
#   'asumido',
#   'factor',
#   'arcóntico',
#   'llegará',
#   'fin',
#   'varios',
#   'movimientos',
#   'finales',
#   'solamente',
#   'acontecimiento'],
#  ['ejemplo',
#   'tercera',
#   'guerra',
#   'mundial',
#   'parte',
#   'escenificada',
#   'parte',
#   'real'],
#  ['evento',
#   'simulado',
#   'invasión',
#   'alienígena',
#   'utilización',
#   'armas',
#   'holográficamente',
#   'encubiertas',
#   'desarrollado',
#   'programas',
#   'operaciones',
#   'negras'],
#  ['además',
#   'evento',
#   'armageddon',
#   'haciendo',
#   'cumplir',
#   'profecía',
#   'bíblica',
#   'incluyendo',
#   'regreso',
#   'mesías',
#   'operación',
#   'rayo',
#   'azul',
#   'operation',
#   'blue',
#   'beam',
#   'tal',
#   'vez',
#   'coordinación',
#   'tercera',
#   'guerra',
#   'mundial',
#   'ataque',
#   'nuclear',
#   'jerusalén'],
#  ['cualquiera',
#   'caso',
#   'engaño',
#   'arcóntico',
#   'terminará',
#   'último',
#   'acto',
#   'guión',
#   'sido',
#   'dramatizado',
#   'historia',
#   'mundo'],
#  ['acto',
#   'final',
#   'escrito',
#   'libro',
#   'apocalipsis',
#   'antigua',
#   'escritura',
#   'forzada',
#   'aprobada',
#   'incluso',
#   'aquellos',
#   'creen'],
#  ['ilusión',
#   'óptica',
#   've',
#   'propios',
#   'ojos',
#   'realmente',
#   'allí',
#   'menos',
#   'existe',
#   'forma',
#   'supone'],
#  ['espejismo'],
#  ['ilusión',
#   'psicológica',
#   'proyecta',
#   'realidad',
#   'externa',
#   'aquello',
#   'existe',
#   'propia',
#   'psique'],
#  ['tale',
#   'término',
#   'satánico',
#   'término',
#   'comodín',
#   'proyecciones',
#   'paranoicas',
#   'mente',
#   'humana'],
#  ['ilusión',
#   'moral',
#   'atribuye',
#   'capacidades',
#   'conducta',
#   'humana',
#   'condiciones',
#   'aplican',
#   'manera',
#   'seres',
#   'humanos',
#   'realmente',
#   'actúan'],
#  ['ejemplo',
#   'dogma',
#   'religioso',
#   'pecado',
#   'original',
#   'atribuye',
#   'culpa',
#   'acción',
#   'humana',
#   'incluso',
#   'sentirse',
#   'culpable'],
#  ['hacer',
#   'gente',
#   'sienta',
#   'actúe',
#   'culpa',
#   'luego',
#   'decir',
#   'hacen',
#   'debido',
#   'evento',
#   'anterior',
#   'nadie',
#   'experimentado',
#   'ilusión',
#   'moral',
#   'absurda',
#   'extravagancia'],
#  ['supuesto',
#   'pagano',
#   'bondad',
#   'innata',
#   'ver',
#   'marco',
#   'aurelio',
#   'pudiera',
#   'ser',
#   'considerado',
#   'ilusión',
#   'moral'],
#  ['embargo',
#   'evidencia',
#   'personas',
#   'actúan',
#   'partir',
#   'bondad',
#   'innata',
#   'nadie',
#   'decir',
#   'hagan',
#   'suficientemente',
#   'fuerte',
#   'contrasta',
#   'acción',
#   'impulsada',
#   'culpa',
#   'debe',
#   'ser',
#   'artificialmente',
#   'forzada',
#   'exterior',
#   'amenaza',
#   'condenación',
#   'eterna',
#   'ejemplo'],
#  ['ilusiones', 'morales', 'pueden', 'ser', 'sutiles', 'directas'],
#  ['tema',
#   'enorme',
#   'pantano',
#   'terreno',
#   'ideal',
#   'arcontes',
#   'tomen',
#   'última',
#   'resistencia'],
#  ['embargo',
#   'juego',
#   'final',
#   'arcóntico',
#   'escenario',
#   'acontecimientos',
#   'mundiales',
#   'falso',
#   'ataque',
#   'alienígena',
#   'junto',
#   'llegada',
#   'mesías',
#   'holográfico',
#   'sazonado',
#   'fuerte',
#   'dosis',
#   'guerra',
#   'nuclear',
#   'quizas',
#   'modus',
#   'operandi',
#   'parásitos',
#   'alienígenas',
#   'mente',
#   'revela',
#   'dos',
#   'características',
#   'sobresalientes',
#   'ilusión',
#   'moral',
#   'factor',
#   'absurdo'],
#  ['último',
#   'eminente',
#   'si',
#   'preeminente',
#   'consumación',
#   'obras',
#   'ocurrir',
#   'derrotados',
#   'humanidad'],
#  ['deleite', 'autoridades', 'amargo', 'belleza', 'depravada'],
#  ['disfrute', 'engaño', 'diseño', 'carencia', 'divinidad'],
#  ['plan',
#   'diseñaron',
#   'revelador',
#   'liberar',
#   'error',
#   'absurdidad',
#   'sucumbí',
#   'planeado'],
#  ['ilusión', 'moral', 'arcontes', 'autoridad'],
#  ['puesto',
#   'pudieran',
#   'ser',
#   'llamados',
#   'autoridades',
#   'gobernantes',
#   'ilusión',
#   'aplica',
#   'propia',
#   'naturaleza'],
#  ['palabras',
#   'hacen',
#   'cumplir',
#   'ilusión',
#   'propia',
#   'naturaleza',
#   'ejecutar',
#   'efecto',
#   'humanidad'],
#  ['mienten',
#   'hacer',
#   'cumplir',
#   'engaño',
#   'realmente',
#   'zánganos',
#   'impulsados',
#   'mezcla',
#   'envidia',
#   'enemistad'],
#  ['tener',
#   'agenda',
#   'absurdo',
#   'convierte',
#   'táctica',
#   'juego',
#   'final',
#   'firma',
#   'alcance',
#   'total',
#   'esfuerzos',
#   'anthropos'],
#  ['ilusión',
#   'moral',
#   'suprema',
#   'confrontando',
#   'humanidad',
#   'opera',
#   'manera',
#   'aquellos',
#   'falsamente',
#   'asumen',
#   'autoridad',
#   'demandan',
#   'obediencia',
#   'órdenes',
#   'afirmando',
#   'desobediencia',
#   'resultaría',
#   'caos',
#   'social',
#   'anarquía'],
#  ['afirman',
#   'preservar',
#   'orden',
#   'social',
#   'moral',
#   'medio',
#   'reglas',
#   'restricciones',
#   'impuestas',
#   'mantenidas',
#   'pura',
#   'fuerza',
#   'brutal'],
#  ['auto',
#   'nombradas',
#   'autoridades',
#   'propagan',
#   'creencia',
#   'seres',
#   'humanos',
#   'abandonados',
#   'propios',
#   'impulsos',
#   'producirían',
#   'mundo',
#   'desorden',
#   'conflicto',
#   'caos'],
#  ['terroristas', 'potenciales', 'mente', 'autoridades'],
#  ['natural',
#   'libertad',
#   'autonomía',
#   'supuestamente',
#   'peligrosos',
#   'mismos',
#   'debemos',
#   'ser',
#   'frenados',
#   'acorralados',
#   'protegidos',
#   'poder',
#   'superior'],
#  ['resumen',
#   'auto',
#   'denominadas',
#   'autoridades',
#   'afirman',
#   'salvar',
#   'humanidad',
#   'tendencias',
#   'caóticas',
#   'anarquistas',
#   'naturaleza',
#   'humana'],
#  ['quieren',
#   'hacernos',
#   'creer',
#   'solos',
#   'dominación',
#   'crearíamos',
#   'mundo',
#   'caos',
#   'social'],
#  ['realidad',
#   'evidencia',
#   'día',
#   'día',
#   'muestra',
#   'aparentemente',
#   'organizan',
#   'provocan',
#   'caos',
#   'mantener',
#   'intento',
#   'controlar',
#   'mundo'],
#  ['menudo',
#   'hacen',
#   'punto',
#   'absurdidad',
#   'teatral',
#   'produciría',
#   'carcajadas',
#   'burla',
#   'ridículo',
#   'si',
#   'siendo',
#   'actuada',
#   'escenario',
#   'público'],
#  ['embargo', 'pasa', 'ser', 'normal'],
#  ['revisión', 'autoridades', 'niño', 'sospechoso', 'terrorismo'],
#  ['ejemplo',
#   'extremo',
#   'absurdo',
#   'extremo',
#   'autoridades',
#   'consumación',
#   'obras'],
#  ['desafortunadamente',
#   'absurdo',
#   'comportamiento',
#   'tipo',
#   'acto',
#   'violación'],
#  ['puede', 'ser', 'mortal', 'asesino'],
#  ['alentado', 'legitimidad', 'concedida', 'autoridades'],
#  ['complejo', 'hace', 'personas', 'actúen', 'inhumanamente'],
#  ['mentira',
#   'acerca',
#   'naturaleza',
#   'propia',
#   'poner',
#   'peligro',
#   'impulsos',
#   'humanos',
#   'insidiosa'],
#  ['representa', 'raíz', 'todas', 'variantes', 'mal', 'social'],
#  ['ilusión',
#   'moral',
#   'particular',
#   'último',
#   'desafío',
#   'discernimiento',
#   'humano',
#   'prueba',
#   'suprema',
#   'genuina',
#   'integridad',
#   'moral',
#   'especie'],
#  ['romper', 'través', 'clave', 'liberación', 'engaño', 'arcóntico'],
#  ['gnósticos',
#   'enseñaban',
#   'mal',
#   'poder',
#   'autónomo',
#   'cosmos',
#   'sino',
#   'fenómeno',
#   'desviación',
#   'surge',
#   'amparo',
#   'engaño'],
#  ['engaño', 'ocultación', 'mal', 'puede', 'cometer'],
#  ['debido',
#   'siendo',
#   'expuesto',
#   'opuesto',
#   'inmediatamente',
#   'derrotado',
#   'tendencia',
#   'natural',
#   'naturaleza',
#   'humana',
#   'elegir',
#   'verdad',
#   'bondad',
#   'convivencia'],
#  ['autoridades',
#   'afirman',
#   'tendencias',
#   'naturales',
#   'deben',
#   'ser',
#   'reprimidas',
#   'controladas',
#   'si',
#   'totalmente',
#   'erradicadas',
#   'reemplazadas',
#   'obediencia',
#   'robótica'],
#  ['poder',
#   'autoridades',
#   'ilusión',
#   'moral',
#   'forzada',
#   'mentira',
#   'tan',
#   'transparente',
#   'necesita',
#   'aplicación',
#   'continua',
#   'fuerza',
#   'bruta',
#   'ser',
#   'sostenida'],
#  ['mentira',
#   'contrario',
#   'verdad',
#   'sólo',
#   'libertad',
#   'explorar',
#   'expresar',
#   'tendencias',
#   'naturales',
#   'permitirá',
#   'humanidad',
#   'alcanzar',
#   'verdadero',
#   'potencial'],
#  ['libertad', 'verdadera', 'anarquía', 'vida', 'tierra'],
#  ['base',
#   'confianza',
#   'sabiduría',
#   'diosa',
#   'sophia',
#   'fundamento',
#   'dependencia',
#   'especies',
#   'diseñó'],
#  ['textos',
#   'gnósticos',
#   'desarrollan',
#   'tema',
#   'diosa',
#   'desea',
#   'humanidad',
#   'través',
#   'humanidad',
#   'suele',
#   'llamar',
#   'pistis',
#   'fe',
#   'confianza'],
#  ['pistis',
#   'sophia',
#   'fe',
#   'diosa',
#   'significa',
#   'madre',
#   'planeta',
#   'madre',
#   'tierra',
#   'confianza',
#   'especie',
#   'favorita',
#   'mascota',
#   'ser',
#   'humano'],
#  ['confianza',
#   'brilla',
#   'reto',
#   'divino',
#   'sophia',
#   'expresa',
#   'hora',
#   'afrontar',
#   'señor',
#   'arconte',
#   'aquel',
#   'episodio',
#   'origen',
#   'mundo',
#   'on',
#   'the',
#   'origin',
#   'of',
#   'the',
#   'world'],
#  ['drama',
#   'cosmológico',
#   'escenario',
#   'cósmico',
#   'reto',
#   'social',
#   'existencial',
#   'viene',
#   'ser',
#   'promulgado',
#   'escenario',
#   'mundial',
#   'tiempo',
#   'momentos'],
#  ['fruto', 'veneno', 'cura', 'promesa', 'muerte', 'vida'],
#  ['cuanto',
#   'diseño',
#   'vida',
#   'implante',
#   'falsea',
#   'verdadero',
#   'diseño',
#   'voy',
#   'enseñar',
#   'acerca',
#   'misterio',
#   'maneras'],
#  ['espíritu',
#   'falsificación',
#   'antimimon',
#   'pneuma',
#   'poder',
#   'gastando',
#   'broma',
#   'dentro',
#   'conduce',
#   'mal',
#   'camino'],
#  ['ello',
#   'vez',
#   'llevan',
#   'mal',
#   'camino',
#   'desviando',
#   'verdadero',
#   'potencial',
#   'anthropos',
#   'fin',
#   'pueda',
#   'saber',
#   'propia',
#   'plenitud',
#   'don',
#   'infinito'],
#  ['árbol', 'diseño', 'amargura', 'ramas', 'oscurecidas', 'muerte'],
#  ['hojas', 'odio', 'engaño', 'aroma', 'rebosa', 'mal', 'poneria'],
#  ['genio',
#   'creación',
#   'mitos',
#   'gnósticos',
#   'inherente',
#   'doble',
#   'aspecto',
#   'mensaje',
#   'humanidad'],
#  ['presenta',
#   'clara',
#   'veraz',
#   'descripción',
#   'hechos',
#   'realmente',
#   'ocurrieron',
#   'reinos',
#   'cósmicos',
#   'participación',
#   'eón',
#   'sophia',
#   'arcontes',
#   'convierte',
#   'escenario',
#   'cósmico',
#   'lleno',
#   'marco',
#   'condiciones',
#   'sociales',
#   'psicológicas',
#   'existenciales',
#   'reflejadas',
#   'situaciones',
#   'reales',
#   'enfrenta',
#   'humanidad',
#   'prueba',
#   'poseer',
#   'poner',
#   'práctica',
#   'potencial',
#   'divino'],
#  ['conocimiento', 'vivo', 'único', 'puede', 'desterrar', 'terrorismo'],
#  ['enfrentar',
#   'terrorismo',
#   'firma',
#   'autoridades',
#   'debe',
#   'estudiarse',
#   'mismo',
#   'preguntar'],
#  ['¿qué', 'vivo'],
#  ['¿no', 'amor', 'libertad', 'ser', 'hacer', 'usted', 'gusta', 'dañar'],
#  ['si',
#   'respuesta',
#   'menos',
#   'usted',
#   'bien',
#   'pudiera',
#   'preparado',
#   'esquema',
#   'globalista',
#   'esclavitud',
#   'momentos',
#   'acercándose',
#   'escenario',
#   'juegofinal'],
#  ['historia',
#   'visión',
#   'sophianic',
#   'misterios',
#   'actional',
#   'capaz',
#   'ser',
#   'promulgado'],
#  ['tal',
#   'acción',
#   'ser',
#   'apoyada',
#   'conocimiento',
#   'específico',
#   'experiencia',
#   'supervivencia',
#   'humana'],
#  ['principal',
#   'experiencia',
#   'capacidad',
#   'descubrir',
#   'depredadores',
#   'psicópatas'],
#  ['representa',
#   'especie',
#   'método',
#   'telestico',
#   'forense',
#   'detectar',
#   'cruel',
#   'engaño',
#   'autoridades'],
#  ['derivado',
#   'palabra',
#   'griega',
#   'poneria',
#   'encontrada',
#   'escritos',
#   'gnósticos',
#   'arriba',
#   'ponerología',
#   'diagnóstico',
#   'deconstrucción',
#   'causas',
#   'mecanismos',
#   'mal',
#   'social'],
#  ['lobaczewski',
#   'utiliza',
#   'sorprendente',
#   'término',
#   'patocracia',
#   'describir',
#   'dominación',
#   'sociedad',
#   'facción',
#   'miembros',
#   'psicópatas',
#   'estimados',
#   'ser',
#   'ciento',
#   'población'],
#  ['si',
#   'usted',
#   'puede',
#   'perfilar',
#   'psicópata',
#   'usted',
#   'miembro',
#   'responsable',
#   'sociedad',
#   'humana'],
#  ['si',
#   'usted',
#   'puede',
#   'detectar',
#   'vencer',
#   'comportamiento',
#   'psicopático',
#   'presenta',
#   'mismo',
#   'realidad',
#   'personal',
#   'inmediata',
#   'usted',
#   'calificado',
#   'vivir',
#   'mundo',
#   'libre'],
#  ['libertad', 'almuerzo', 'gratis'],
#  ['tal', 'humilde', 'opinión', 'guerrero', 'equio', 'kali'],
#  ['último',
#   'podría',
#   'decir',
#   'desafío',
#   'presentado',
#   'señor',
#   'arconte',
#   'sophia',
#   'representa',
#   'forma',
#   'humanidad',
#   'compromete',
#   'corrección',
#   'regresa',
#   'experiencia',
#   'divina',
#   'libre',
#   'interrupciones',
#   'subterfugios',
#   'arcónticos'],
#  ['diosa', 'sabiduría', 'cuenta', 'especie', 'hacer', 'precisamente'],
#  ['embargo',
#   'pude',
#   'requerir',
#   'demasiado',
#   'gran',
#   'tramo',
#   'imaginación',
#   'darse',
#   'cuenta',
#   'proposición',
#   'confianza',
#   'divina',
#   'ser',
#   'humano',
#   'mortal'],
#  ['poner',
#   'misma',
#   'proposición',
#   'estricto',
#   'lenguaje',
#   'secular',
#   'podemos',
#   'darnos',
#   'cuenta',
#   'verdadera',
#   'humanidad',
#   'golpear',
#   'autoridades'],
#  ['manera',
#   'hacerlo',
#   'forma',
#   'central',
#   'decisiva',
#   'elegir',
#   'anarquía',
#   'desafío',
#   'cualquier',
#   'autoridad',
#   'demuestre',
#   'benevolencia',
#   'hacia',
#   'vida',
#   'todas',
#   'formas'],
#  ['verdadera',
#   'anarquía',
#   'especie',
#   'humana',
#   'garantía',
#   'sophia',
#   'éxito',
#   'divino',
#   'experimento',
#   'preconcibió',
#   'anthropos',
#   'establecer',
#   'fin',
#   'predeterminado'],
#  ['gnosis',
#   'hoy',
#   'espiritualidad',
#   'abierta',
#   'potenciación',
#   'código',
#   'imaginal',
#   'moral',
#   'optimiza',
#   'perspectivas',
#   'anarquía',
#   'creativa'],
#  ['así',
#   'gnosis',
#   'podemos',
#   'cumplir',
#   'promesa',
#   'edénica',
#   'vida',
#   'tierra'],
#  ['incluso', 'palabra', 'lleva', 'mensaje', 'esencial'],
#  ['an', 'arc', 'autoridad', 'arcontes'],
#  ['señalado',
#   'compromiso',
#   'corrección',
#   'sophia',
#   'proceso',
#   'voluntario',
#   'implica',
#   'acto',
#   'des',
#   'selección',
#   'cada',
#   'individuo',
#   'humano'],
#  ['dar',
#   'marcha',
#   'atrás',
#   'amenazante',
#   'absurdo',
#   'autoridades',
#   'des',
#   'selecciona',
#   'corrección'],
#  ['haciendo',
#   'renuncia',
#   'verdadera',
#   'identidad',
#   'ser',
#   'humano',
#   'oportunidad',
#   'vivir',
#   'desarrollarse',
#   'miembro',
#   'activo',
#   'funciones',
#   'anthropos'],
#  ['arcontes', 'obligaron', 'hacerlo'],
#  ['usted', 'pierde', 'papel', 'corrección', 'sophia'],
#  ['usted',
#   'derrota',
#   'mismo',
#   'perdiendo',
#   'mayor',
#   'oportunidad',
#   'vida',
#   'puede',
#   'ofrecerle'],
#  ['autoridades',
#   'sólo',
#   'cedido',
#   'poder',
#   'través',
#   'ignorancia',
#   'negación',
#   'potencial',
#   'divino',
#   'dotación',
#   'madre',
#   'animal',
#   'planetaria',
#   'eones'],
#  ['pasaje',
#   'segundo',
#   'tratado',
#   'gran',
#   'seth',
#   'the',
#   'second',
#   'treatise',
#   'of',
#   'the',
#   'great',
#   'seth',
#   'capta',
#   'tragedia',
#   'básica',
#   'raza',
#   'humana'],
#  ['ser',
#   'engañado',
#   'verdadero',
#   'potencial',
#   'medio',
#   'simulación',
#   'cayendo',
#   'versión',
#   'falsa',
#   'mismo'],
#  ['advertencia',
#   'parece',
#   'ser',
#   'exclusiva',
#   'protesta',
#   'radical',
#   'gnósticos'],
#  ['palabras',
#   'aplicadas',
#   'aquí',
#   'jesús',
#   'moisés',
#   'patriarcas',
#   'puede',
#   'ser',
#   'aplicada',
#   'aquellos',
#   'raza',
#   'humana',
#   'sucumben',
#   'ilusión',
#   'moral',
#   'autoridades'],
#  ['nunca', 'conocieron', 'verdad'],
#  ['conocerán'],
#  ['gran', 'engaño'],
#  ['alma', 'pueden'],
#  ['nunca', 'encontrar', 'espíritu'],
#  ['libertad', 'fin', 'conocer'],
#  ['mismos', 'verdadera', 'humanidad'],
#  ['manera', 'superar', 'conspiración'],
#  ['makia',
#   'freeman',
#   'editora',
#   'the',
#   'freedom',
#   'articles',
#   'investigadora',
#   'principal',
#   'toolsforfreedom',
#   'com',
#   'escribiendo',
#   'aspectos',
#   'verdad',
#   'libertad',
#   'exponiendo',
#   'aspectos',
#   'conspiración',
#   'mundial',
#   'sugerir',
#   'soluciones',
#   'cómo',
#   'humanidad',
#   'puede',
#   'crear',
#   'nuevo',
#   'sistema',
#   'paz',
#   'abundancia'],
#  ['permitirá', 'superar', 'conspiración', 'nuevo', 'orden', 'mundial'],
#  ['poderoso', 'puede', 'ser', 'engañado', 'controlado'],
#  ['amor',
#   'miedo',
#   'centro',
#   'cualquier',
#   'solución',
#   'superación',
#   'conspiración',
#   'control',
#   'nuevo',
#   'orden',
#   'mundial',
#   'newworldorder',
#   'crecido',
#   'oscuridad',
#   'alrededor'],
#  ['puede',
#   'sonar',
#   'trillado',
#   'puede',
#   'sonar',
#   'hippie',
#   'puede',
#   'sonar',
#   'tonto',
#   'sólo',
#   'si',
#   'usted',
#   'reconoce',
#   'olvidado',
#   'poder',
#   'amor',
#   'verdad',
#   'amor',
#   'fuerza',
#   'poderosa',
#   'universo'],
#  ['amor', 'poder'],
#  ['misma',
#   'cosa',
#   'sensiblero',
#   'poder',
#   'ama',
#   'poderosa',
#   'energía',
#   'fluye',
#   'través',
#   'cuerpo',
#   'emana',
#   'fuertemente',
#   'usted'],
#  ['corazón',
#   'bombea',
#   'entusiasmo',
#   'elevando',
#   'ánimo',
#   'líder',
#   'legítimo',
#   'cuerpo'],
#  ['corazón', 'líder', 'cuerpo'],
#  ['destinados', 'vivir', 'corazón', 'usarlo', 'guía', 'principal'],
#  ['corazón',
#   'guiar',
#   'si',
#   'equilibrio',
#   'cerebro',
#   'magnífico',
#   'equipo',
#   'herramienta',
#   'puede',
#   'crear',
#   'milagros',
#   'actúa',
#   'servidor',
#   'corazón',
#   'embargo',
#   'mayoría',
#   'olvidado',
#   'verdad',
#   'básica',
#   'vivimos',
#   'vidas',
#   'mayoría',
#   'partir',
#   'cerebro',
#   'especialmente',
#   'lado',
#   'izquierdo',
#   'cerebro',
#   'lado',
#   'masculino',
#   'lógico'],
#  ['igual', 'gobierno', 'cerebro', 'excelente', 'sirviente', 'amo', 'terrible'],
#  ['caída',
#   'hombre',
#   'escrito',
#   'hablado',
#   'muchas',
#   'tradiciones',
#   'religiosas',
#   'culturales',
#   'esla',
#   'caída',
#   'corazón',
#   'elcerebro',
#   'pérdida',
#   'amor',
#   'poder',
#   'conexión',
#   'infinito'],
#  ['ciencia', 'empezando', 'demostrar', 'verdadero', 'poder', 'delcorazón'],
#  ['comparación',
#   'campo',
#   'electromagnético',
#   'producido',
#   'cerebro',
#   'componente',
#   'eléctrico',
#   'campo',
#   'corazón',
#   'aproximadamente',
#   'veces',
#   'mayor',
#   'amplitud',
#   'impregna',
#   'cada',
#   'célula',
#   'cuerpo'],
#  ['componente',
#   'magnético',
#   'aproximadamente',
#   'veces',
#   'fuerte',
#   'campo',
#   'magnético',
#   'cerebro',
#   'puede',
#   'ser',
#   'detectado',
#   'varios',
#   'pies',
#   'distancia',
#   'cuerpo',
#   'magnetómetros',
#   'sensibles'],
#  ['aquellos',
#   'acostumbrados',
#   'hechos',
#   'cifras',
#   'lógica',
#   'razón',
#   'realmente',
#   'información',
#   'bastante',
#   'sorprendente'],
#  ['parte',
#   'trabajo',
#   'drunvalo',
#   'melquisedec',
#   'nassim',
#   'haramein',
#   'muestran',
#   'corazón',
#   'centro',
#   'ser',
#   'lugar',
#   'auras',
#   'energéticas',
#   'cuerpos',
#   'luz',
#   'campos',
#   'electromagnéticos',
#   'fuentes',
#   'campos',
#   'toroidales',
#   'clave',
#   'trascender',
#   'realidad',
#   'manifestando',
#   'milagros',
#   'liberarse',
#   'lamatrix'],
#  ['cerebro', 'puede', 'lograr', 'solo', 'importa', 'imagina'],
#  ['debe', 'ser', 'disparado', 'energizado', 'poder', 'corazón'],
#  ['ama', 'tema'],
#  ['corazón', 'fuerte', 'usted', 'cree'],
#  ['elegimos',
#   'varias',
#   'veces',
#   'miedo',
#   'amor',
#   'inconscientemente',
#   'invitamos',
#   'tiranía',
#   'todas',
#   'formas',
#   'oscuridad',
#   'obtener',
#   'mayor',
#   'presencia',
#   'corazones',
#   'mentes',
#   'comunidades',
#   'países'],
#  ['controladores',
#   'nuevo',
#   'orden',
#   'mundial',
#   'saben',
#   'bien',
#   'aprovechado',
#   'gente',
#   'largo',
#   'milenios',
#   'mediante',
#   'inducción',
#   'miedo'],
#  ['hoy',
#   'día',
#   'ladifusión',
#   'miedose',
#   'convertido',
#   'modus',
#   'operandi',
#   'obvio',
#   'medios',
#   'decomunicación',
#   'propiedad',
#   'mismo',
#   'grupo',
#   'personas',
#   'dirigen',
#   'elmundo'],
#  ['saben',
#   'miles',
#   'millones',
#   'sintonizando',
#   'cnn',
#   'bbc',
#   'cualquier',
#   'organismo',
#   'radiodifusión',
#   'miedo',
#   'última',
#   'instancia',
#   'cerebros',
#   'corazones',
#   'sintonía',
#   'algún',
#   'tipo',
#   'miedo',
#   'ansiedad',
#   'preocupación',
#   'odio',
#   'ira',
#   'autocompasión',
#   'etc'],
#  ['resistir',
#   'verdad',
#   'nuevo',
#   'orden',
#   'mundial',
#   'defender',
#   'libertad',
#   'necesario',
#   'prestar',
#   'atención',
#   'mundo',
#   'interior',
#   'mundo',
#   'exterior'],
#  ['importante',
#   'crear',
#   'conciencia',
#   'losogm',
#   'estelas',
#   'químicas',
#   'engañogubernamental',
#   'importante',
#   'exponer',
#   'corrupción',
#   'mantener',
#   'tiranos',
#   'responsables',
#   'si',
#   'hace',
#   'eligiendo',
#   'temor',
#   'amor',
#   'conspiración',
#   'nunca',
#   'acaba'],
#  ['aunque',
#   'nuevo',
#   'orden',
#   'mundial',
#   'derrotado',
#   'algún',
#   'tipo',
#   'tiranía',
#   'saltará',
#   'inmediatamente',
#   'llenar',
#   'vacío'],
#  ['sólo',
#   'masa',
#   'crítica',
#   'gente',
#   'elige',
#   'constantemente',
#   'amor',
#   'miedo',
#   'puede',
#   'conspiración',
#   'control',
#   'finalmente',
#   'llegar',
#   'fin',
#   'cada',
#   'responsable',
#   'propio',
#   'interno'],
#  ['manera',
#   'cada',
#   'individuo',
#   'maravilloso',
#   'único',
#   'poder',
#   'tomar',
#   'decisiones',
#   'desempeñar',
#   'parte',
#   'restauración',
#   'libertad',
#   'mundo'],
#  ['usted', 'mismo', 'reservas'],
#  ['sólo', 'sé', 'mismo', 'reservas'],
#  ['vas', 'inspirar', 'hacer', 'mismo'],
#  ['conspiradores', 'temen', 'gente', 'miedo'],
#  ['usted', 'mismo', 'reservas'],
#  ['usted',
#   'mismo',
#   'miedo',
#   'preocuparse',
#   'futuro',
#   'preocupado',
#   'fracaso',
#   'importarle',
#   'piensen',
#   'demás'],
#  ['parte',
#   'serie',
#   'camino',
#   'superar',
#   'conspiracióny',
#   'mire',
#   'tremendo',
#   'poder',
#   'ganan',
#   'personas',
#   'simplemente',
#   'deciden',
#   'ser',
#   'mismos',
#   'dejar',
#   'retenerse',
#   'impiden',
#   'avanzar',
#   'algún',
#   'nivel'],
#  ['quizás',
#   'miedo',
#   'ser',
#   'vulnerables',
#   'expresar',
#   'demasiado',
#   'sentimientos',
#   'grande',
#   'así',
#   'muchas',
#   'sociedades',
#   'caracterizadas',
#   'represión',
#   'emocional',
#   'oeste',
#   'negro',
#   'blanco',
#   'inglaterra',
#   'alemania',
#   'australia',
#   'tailandia',
#   'japón'],
#  ['particular',
#   'ideal',
#   'británico',
#   'labio',
#   'superior',
#   'tieso',
#   'sólo',
#   'causado',
#   'sufrimientos',
#   'indecibles',
#   'aquellos',
#   'regularmente',
#   'rellenan',
#   'sentimientos',
#   'viven',
#   'vidas',
#   'silenciosa',
#   'desesperación'],
#  ['quizás', 'miedo', 'preocupados', 'defecto'],
#  ['embargo', 'definimos', 'fracaso'],
#  ['einstein',
#   'dijo',
#   'vez',
#   'cualquier',
#   'persona',
#   'nunca',
#   'cometido',
#   'error',
#   'nunca',
#   'intentado',
#   'nuevo'],
#  ['edison',
#   'vio',
#   'bien',
#   'cosas',
#   'dijo',
#   'ser',
#   'preguntado',
#   'tal',
#   'fallar',
#   'repetidamente',
#   'diseñar',
#   'bombilla',
#   'luz',
#   'fallado'],
#  ['acabo', 'encontrar', 'maneras', 'funcionan'],
#  ['parte', 'tal', 'vez', 'miedo', 'piensen'],
#  ['puede',
#   'ser',
#   'gran',
#   'trampa',
#   'seres',
#   'humanos',
#   'criaturas',
#   'sociales',
#   'lugar',
#   'dudas',
#   'parece',
#   'fuerte',
#   'instinto',
#   'primario',
#   'aceptación',
#   'encajar',
#   'parte',
#   'manada'],
#  ['si',
#   'necesidad',
#   'templada',
#   'auto',
#   'conocimiento',
#   'coraje',
#   'serquienes',
#   'realmente',
#   'entonces',
#   'puede',
#   'conducir',
#   'pasividad',
#   'desear',
#   'querer',
#   'mover',
#   'bote',
#   'fácilmente',
#   'manipulado',
#   'conspiradores',
#   'nuevo',
#   'orden',
#   'mundial'],
#  ['difícil', 'resumir', 'mejor', 'palabras', 'mariannewilliamson', 'escribió'],
#  ['miedo', 'profundo', 'inadecuados'],
#  ['miedo',
#   'profundo',
#   'poderosos',
#   'medida',
#   'luz',
#   'oscuridad',
#   'asusta',
#   'preguntamos',
#   '¿quién',
#   'ser',
#   'brillante',
#   'magnífico',
#   'talentoso',
#   'fabuloso',
#   'realidad',
#   '¿quién',
#   'usted',
#   'serlo',
#   'usted',
#   'hijo',
#   'dedios'],
#  ['pequeñez',
#   'sirve',
#   'mundo',
#   'iluminado',
#   'encogerse',
#   'personas',
#   'sientan',
#   'inseguras',
#   'alrededor'],
#  ['destinados',
#   'brillar',
#   'hacen',
#   'niños',
#   'nacimos',
#   'manifestar',
#   'gloria',
#   'dediosque',
#   'sólo',
#   'permitimos',
#   'luz',
#   'brille',
#   'inconscientemente',
#   'damos',
#   'permiso',
#   'hacer',
#   'mismo'],
#  ['liberarnos', 'propio', 'miedo', 'presencia', 'automáticamente', 'libera'],
#  ['ahí',
#   'verdadero',
#   'secreto',
#   'acabar',
#   'nuevo',
#   'orden',
#   'mundial',
#   'conspiración',
#   'control',
#   'amenaza',
#   'esclavizar',
#   'planeta'],
#  ['siendo',
#   'verdaderamente',
#   'usted',
#   'mismo',
#   'reservas',
#   'enciende',
#   'chispa',
#   'ayuda',
#   'conspiradores',
#   'temen',
#   'gente',
#   'miedo',
#   'deciden',
#   'expresarse',
#   'plenamente',
#   'mismos',
#   'completo',
#   'tipo',
#   'personas',
#   'pueden',
#   'ser',
#   'controlados'],
#  ['resisten',
#   'conformidad',
#   'uniformidad',
#   'obediencia',
#   'sumisa',
#   'dedican',
#   'sumisión',
#   'ciega',
#   'autoridad',
#   'fácilmente',
#   'corrompidos',
#   'pervertidos',
#   'engañados',
#   'llevar',
#   'cabo',
#   'órdenes',
#   'simplemente',
#   'hacer',
#   'trabajo'],
#  ['conocen',
#   'acciones',
#   'van',
#   'dejarse',
#   'utilizar',
#   'traer',
#   'existencia',
#   'hacer',
#   'cumplir',
#   'dictadura',
#   'mundial',
#   'totalitaria'],
#  ['usted', 'mismo', '¡nadie', 'puede'],
#  ['usted',
#   'mismo',
#   '¡todos',
#   'demás',
#   'tomados',
#   'usted',
#   'mismo',
#   'reservas'],
#  ['disculpe',
#   'nadie',
#   'quién',
#   'realmente',
#   'instale',
#   'ningún',
#   'tipo',
#   'tensión',
#   'lucha',
#   'interna',
#   'negar',
#   'magnificencia',
#   'poder',
#   'belleza',
#   'realidad',
#   'quién',
#   'usted'],
#  ['conforme',
#   'bien',
#   'conformidad',
#   'dolor',
#   'sentirá',
#   'ser',
#   'auténtico',
#   'mayor',
#   'cualquier',
#   'posible',
#   'ganancia',
#   'obtiene',
#   'esconder',
#   'luz',
#   'pretender',
#   'ser',
#   'alguien'],
#  ['vez',
#   'suficientes',
#   'decidamos',
#   'ser',
#   'mismos',
#   'conspiración',
#   'mundial',
#   'derrumbará',
#   'sólo',
#   'apoya',
#   'hombros',
#   'ignorantes',
#   'aquellos',
#   'olvidado',
#   'infinitamente',
#   'poderosos'],
#  ['si', 'usted', 'gobierna', 'mismo'],
#  ['libre', 'reducirá', 'necesidad'],
#  ['autoridad', 'gobierno'],
#  ['manera',
#   'usted',
#   'necesita',
#   'nadie',
#   'haga',
#   'usted',
#   'importante',
#   'permita',
#   'nadie',
#   'haga',
#   'usted'],
#  ['parte',
#   'serie',
#   'camino',
#   'superar',
#   'conspiración',
#   'destinada',
#   'ayudar',
#   'persona',
#   'promedio',
#   'sentir',
#   'poder',
#   'sentirse',
#   'menos',
#   'abrumada',
#   'enfrentarse',
#   'conspiración',
#   'nuevo',
#   'orden',
#   'mundial',
#   'nwo'],
#  ['gobierno',
#   'hoy',
#   'peligroso',
#   'tiránico',
#   'control',
#   'preocupe',
#   '¡hay',
#   'podemos',
#   'hacer',
#   'respecto'],
#  ['¿qué', 'significa', 'gobernarse', 'usted', 'mismo'],
#  ['gobernarse',
#   'usted',
#   'mismo',
#   'cuidar',
#   'vida',
#   'asuntos',
#   'medios',
#   'vida',
#   'relaciones',
#   'necesidad',
#   'ayuda',
#   'interferencia',
#   'externa',
#   'significa',
#   'usted',
#   'independiente',
#   'responsable',
#   'autosuficiente',
#   'significa',
#   'usted',
#   'hacer',
#   'mismo',
#   'vivir',
#   'lugar',
#   'aislado',
#   'cultivar',
#   'toda',
#   'propia',
#   'comida',
#   'contacto',
#   'mundo',
#   'exterior'],
#  ['gente',
#   'negociando',
#   'interactuando',
#   'albores',
#   'hombre',
#   'quiere',
#   'decir',
#   'usted',
#   'comercia',
#   'usted',
#   'hace',
#   'manera',
#   'justa',
#   'honorable',
#   'manteniendo',
#   'acuerdos',
#   'usando',
#   'engaño',
#   'mientras',
#   'usted',
#   'robe',
#   'mienta',
#   'engañe',
#   'demás',
#   'sentirán',
#   'agraviados',
#   'usted',
#   'tratarán',
#   'corregir',
#   'mal'],
#  ['significa',
#   'pueden',
#   'apelar',
#   'autoridades',
#   'externas',
#   'hacer',
#   'trae',
#   'concepto',
#   'gobierno'],
#  ['gobernarse',
#   'verdaderamente',
#   'mismo',
#   'significa',
#   'asegurar',
#   'todas',
#   'relaciones',
#   'llevan',
#   'cabo',
#   'integridad',
#   'nadie',
#   'nunca',
#   'necesidad',
#   'demandarle',
#   'presentar',
#   'demanda',
#   'usted',
#   'incluso',
#   'llevar',
#   'algún',
#   'tipo',
#   'autoridad',
#   'externa',
#   'resolver',
#   'disputa',
#   'usted',
#   'podría',
#   'resolver',
#   'cosas',
#   'nadie',
#   'llegar',
#   'punto'],
#  ['usted',
#   'realmente',
#   'gobierna',
#   'mismo',
#   'necesidad',
#   'fuerza',
#   'gobierno',
#   'externo',
#   'desaparece'],
#  ['si',
#   'usted',
#   'toma',
#   'responsabilidad',
#   'mismo',
#   'necesario',
#   'llamados',
#   'representantes',
#   'traten',
#   'tomar',
#   'responsabilidad',
#   'usted',
#   'afirmar',
#   'control',
#   'usted'],
#  ['responsabilidad'],
#  ['¿por', 'importante', 'usted', 'mismo', 'gobierne'],
#  ['usted', 'gobierna', 'mismo', 'usted', 'toma', 'asunto', 'propias', 'manos'],
#  ['usted',
#   'comienza',
#   'persona',
#   'espejo',
#   'recuerde',
#   'mayor',
#   'ámbito',
#   'influencia',
#   'usted',
#   'puede',
#   'controlar',
#   'propios',
#   'pensamientos',
#   'palabras',
#   'acciones',
#   'usted',
#   'puede',
#   'controlar',
#   'acuerdos',
#   'secretos',
#   'políticos',
#   'corruptos',
#   'escenario',
#   'mundial',
#   'usted',
#   'puede',
#   'asegurar',
#   'usted',
#   'conduce',
#   'negocio',
#   'vida',
#   'personal',
#   'manera',
#   'justa',
#   'honesta'],
#  ['piense',
#   'si',
#   'mundo',
#   'empezara',
#   'gobernarse',
#   'mismos',
#   'resolverían',
#   'disputas',
#   'mismos',
#   'eliminando',
#   'así',
#   'necesidad',
#   'tantas',
#   'reglas',
#   'regulaciones',
#   'resumen',
#   'reduciría',
#   'dependencia',
#   'ley'],
#  ['menos',
#   'necesidad',
#   'ley',
#   'menos',
#   'necesidad',
#   'policía',
#   'hacer',
#   'cumplir',
#   'ley',
#   'menos',
#   'necesidad',
#   'tribunales',
#   'jueces',
#   'adjudicar',
#   'ley',
#   'equivale',
#   'automáticamente',
#   'menos',
#   'tiranía'],
#  ['fórmula',
#   'directa',
#   'aquí',
#   'aumentar',
#   'auto',
#   'responsabilidad',
#   'aumentar',
#   'auto',
#   'libertad',
#   'simplemente',
#   'aumentar',
#   'responsabilidad',
#   'aumentar',
#   'libertad'],
#  ['además',
#   'si',
#   'gente',
#   'empezara',
#   'gobernarse',
#   'mismos',
#   'mejor',
#   'incluiría',
#   'pensamientocrítico',
#   'puede',
#   'externalizar',
#   'pensamiento',
#   'crítico',
#   'aunque',
#   'parece',
#   'educación',
#   'enseñanza',
#   'general',
#   'fundada',
#   'rockefeller',
#   'tratando',
#   'engañarnos',
#   'hacer',
#   'véase',
#   'deliberate',
#   'dumbing',
#   'down',
#   'of',
#   'america'],
#  ['usted',
#   'pensar',
#   'usted',
#   'mismo',
#   'nadie',
#   'puede',
#   'pensar',
#   'usted',
#   'gobernarse',
#   'usted',
#   'mismo',
#   'significa',
#   'pensar',
#   'usted',
#   'mismo',
#   'cuidadosamente',
#   'evaluar',
#   'información',
#   'presenta',
#   'gobiernan',
#   'mismos',
#   'menos',
#   'susceptibles',
#   'propaganda',
#   'engañosa',
#   'lavado',
#   'cerebro',
#   'dependen',
#   'tiranías',
#   'nuevo',
#   'orden',
#   'mundial'],
#  ['finaliza', 'ignorancia', 'usted', 'terminará', 'sistema', 'control'],
#  ['si',
#   'usted',
#   'gobierna',
#   'mismo',
#   '¿usted',
#   'realmente',
#   'superará',
#   'conspiración'],
#  ['si', 'usted', 'gobierna', 'usted', 'mismo', 'podrá', 'ser', 'soberano'],
#  ['cantidad',
#   'control',
#   'gobierno',
#   'usted',
#   'disminuirá',
#   'número',
#   'suficiente',
#   'hagamos',
#   'alcance',
#   'masa',
#   'crítica',
#   'sociedad',
#   'va',
#   'cambiar',
#   'tamaño',
#   'gobierno',
#   'reducirá',
#   'desapareciendo',
#   'completo',
#   'menos',
#   'quedando',
#   'limitado',
#   'alcance',
#   'intención',
#   'original',
#   'establecimiento',
#   'unidos',
#   'naciones'],
#  ['recuerde',
#   'responsabilidad',
#   'investigar',
#   'comprender',
#   'fuerzas',
#   'rigen',
#   'usted'],
#  ['vez',
#   'usted',
#   'recupere',
#   'nuevo',
#   'poder',
#   'haga',
#   'posible',
#   'mejorar',
#   'manejo',
#   'propios',
#   'asuntos',
#   'vida',
#   'usted',
#   'sorprenderá',
#   'cuán',
#   'libre',
#   'usted',
#   'inspirará',
#   'ayudar',
#   'superar',
#   'conspiración',
#   'enfrentamos'],
#  ['gran', 'secreto', 'manos', 'aquellos', 'cabeza', 'conspiración', 'mundial'],
#  ['usted', 'puede', 'elegir', 'vibración', 'ser', 'libre'],
#  ['proactivo',
#   'decida',
#   'elegir',
#   'actitud',
#   'emoción',
#   'usted',
#   'saluda',
#   'cada',
#   'persona',
#   'situación',
#   'vida'],
#  ['parte',
#   'dela',
#   'seriela',
#   'manera',
#   'superar',
#   'conspiración',
#   'escrita',
#   'ayudarle',
#   'darse',
#   'cuenta',
#   'aunque',
#   'conspiración',
#   'mundial',
#   'fuerzas',
#   'oscuras',
#   'controlan',
#   'mundo',
#   'cosas',
#   'ven',
#   'sombrías',
#   'última',
#   'instancia',
#   'poder',
#   'superar',
#   'comienza',
#   'usted',
#   'dándose',
#   'cuenta',
#   'si',
#   'usted',
#   'elige',
#   'conscientemente',
#   'quesiente',
#   'usted',
#   'comenzará',
#   'experimentar',
#   'diferentes',
#   'cosas',
#   'vida'],
#  ['definitiva',
#   'usted',
#   'va',
#   'crear',
#   'realidad',
#   'diferente',
#   'cuanto',
#   'domine',
#   'menos',
#   'usted',
#   'capaz',
#   'ser',
#   'controlado'],
#  ['energía'],
#  ['universo', 'energía'],
#  ['materia',
#   'sólo',
#   'energía',
#   'desacelerada',
#   'ritmo',
#   'lento',
#   'energía',
#   'vibra',
#   'diferentes',
#   'frecuencias',
#   'seres',
#   'energía',
#   'parte',
#   'universo',
#   'emociones',
#   'gran',
#   'parte',
#   'impulsa',
#   'cómo',
#   'expresamos',
#   'energía'],
#  ['enseñado',
#   'acostumbrados',
#   'creer',
#   'acontecimientos',
#   'externos',
#   'dictan',
#   'emociones'],
#  ['ejemplo',
#   'rama',
#   'cae',
#   'rompe',
#   'ventana',
#   'coche',
#   'usted',
#   'triste',
#   'enojado',
#   'usted',
#   'hereda',
#   'dinero',
#   'feliz',
#   'jefe',
#   'despide',
#   'devastado',
#   'usted',
#   'encuentra',
#   'nueva',
#   'novia',
#   'novio',
#   'feliz',
#   'usted',
#   'sigue',
#   'siendo',
#   'detenido',
#   'luces',
#   'rojas',
#   'irritado'],
#  ['casi',
#   'piezas',
#   'software',
#   'informático',
#   'caminando',
#   'ahí',
#   'respuestas',
#   'pre',
#   'programadas',
#   'espera',
#   'ser',
#   'detonado',
#   'forma',
#   'control',
#   'mental'],
#  ['políticos',
#   'saben',
#   'control',
#   'mente',
#   'siempre',
#   'apelan',
#   'miedo',
#   'conseguir',
#   'votos',
#   'si',
#   'amenaza',
#   'conjuran',
#   'hombre',
#   'saco',
#   'bin',
#   'laden',
#   'operación',
#   'bandera',
#   'falsacomo',
#   'tiroteo',
#   'batman',
#   'aurora',
#   'tiroteo',
#   'sandy',
#   'hook',
#   'bombardeo',
#   'maratón',
#   'boston'],
#  ['manipulan', 'vibración', 'usted', 'poder', 'beneficiarse'],
#  ['¿qué',
#   'pasa',
#   'si',
#   'usted',
#   'realmente',
#   'elige',
#   'lugar',
#   'dejar',
#   'eventos',
#   'externos',
#   'dicten'],
#  ['mayores',
#   'secretos',
#   'poder',
#   'aquellos',
#   'cabeza',
#   'conspiración',
#   'mundial',
#   'linajes',
#   'élite',
#   'conocimiento',
#   'esotérico',
#   'ejecutar',
#   'nuevo',
#   'orden',
#   'mundial',
#   'new',
#   'world',
#   'order',
#   'usted',
#   'puede',
#   'elegir',
#   'vibración'],
#  ['palabras',
#   'usted',
#   'puede',
#   'elegir',
#   'manera',
#   'proactiva',
#   'frecuencia',
#   'expresión',
#   'energía'],
#  ['usted',
#   'creador',
#   'cualquier',
#   'ser',
#   'humano',
#   'usted',
#   'puede',
#   'decidir',
#   'sentimiento',
#   'emoción',
#   'adoptar',
#   'forma',
#   'proactiva',
#   'lugar',
#   'reactiva',
#   'ser',
#   'falso',
#   'ser',
#   'usted',
#   'simplemente',
#   'conjurado',
#   'aunque',
#   'puede',
#   'hacer',
#   'principio',
#   'vuelva',
#   'natural',
#   'ahí',
#   'expresiónfingir',
#   'lohaces'],
#  ['hablando',
#   'acerca',
#   'cómo',
#   'ocultar',
#   'suprimir',
#   'genuina',
#   'tristeza',
#   'dolor',
#   'poniendo',
#   'cara',
#   'feliz',
#   'sólo',
#   'represión',
#   'mundo',
#   'lleno',
#   'conduce',
#   'sufrimiento'],
#  ['hablando',
#   'elegir',
#   'emoción',
#   'sentimiento',
#   'actitud',
#   'creencia',
#   'toda',
#   'vibración',
#   'usted',
#   'enfrentan',
#   'nueva',
#   'circunstancia',
#   'vida',
#   'modo',
#   'incluye',
#   'paquete',
#   'usted',
#   'elige',
#   'vibración',
#   'arte',
#   'magia',
#   'realidad',
#   'transforma',
#   'pasa',
#   'usted'],
#  ['responder',
#   'amor',
#   'confianza',
#   'compasión',
#   'cualquier',
#   'persona',
#   'situación',
#   'usted',
#   'convierte',
#   'cada',
#   'problema',
#   'reto',
#   'oportunidad'],
#  ['ejemplo',
#   'rama',
#   'golpea',
#   'coche',
#   'usted',
#   'responde',
#   'gratitud',
#   'gracias',
#   'dios',
#   'ahí',
#   'cayó',
#   'luego',
#   'confianza',
#   'coche',
#   'empezando',
#   'envejecer',
#   'empezando',
#   'necesitar',
#   'nuevo',
#   '¿quién',
#   'sabe',
#   'podría',
#   'vuelta',
#   'esquina'],
#  ['cada',
#   'vez',
#   'destruye',
#   'abre',
#   'puerta',
#   'nuevo',
#   'general',
#   'podemos',
#   'ver'],
#  ['cuanto',
#   'usted',
#   'domine',
#   'flexibilidad',
#   'fuerza',
#   'interior',
#   'actitud',
#   'positiva',
#   'necesaria',
#   'elección',
#   'vibración',
#   'libre'],
#  ['cuanto',
#   'menos',
#   'usted',
#   'caiga',
#   'mensajes',
#   'programados',
#   'miedo',
#   'transmitidos',
#   'constantemente',
#   'principales',
#   'medios',
#   'decomunicación',
#   'número',
#   'suficiente',
#   'elegimos',
#   'vibraciones',
#   'gran',
#   'parte',
#   'tiempo',
#   'toda',
#   'red',
#   'control',
#   'tiranía',
#   'derrumbará',
#   'apoyada',
#   'miedo'],
#  ['tal', 'inconscientemente', 'alimentamos', 'vibraciones', 'miedo'],
#  ['vez',
#   'empezamos',
#   'emitiendo',
#   'vibraciones',
#   'superiores',
#   'tales',
#   'amor',
#   'confianza',
#   'usted',
#   'vuelve',
#   'difícil',
#   'imposible',
#   'controlar',
#   'debido',
#   'reacción',
#   'respuesta',
#   'puede',
#   'predecir',
#   'aman',
#   'dependen',
#   'ninguna',
#   'fuerza',
#   'externa',
#   'proporcionar',
#   'seguridad',
#   'manera',
#   'temen',
#   'dependen'],
#  ['secreto', 'final', 'conspiración'],
#  ['viene',
#   'abajo',
#   'controladores',
#   'nuevo',
#   'orden',
#   'mundial',
#   'gobiernan',
#   'entrado',
#   'propio',
#   'poder'],
#  ['olvidado',
#   'somosdios',
#   'seres',
#   'soberanos',
#   'creadores',
#   'poder',
#   'manifestar',
#   'realidad',
#   'elección',
#   'élite',
#   'quiere',
#   'pensemos',
#   'animal',
#   'ligeramente',
#   'avanzado',
#   'mono',
#   'nacido',
#   'trabajar',
#   'consumir',
#   'morir'],
#  ['usted',
#   'maestro',
#   'creador',
#   'disfrazado',
#   '¡despiértese',
#   'usted',
#   'puede',
#   'crear',
#   'quiera',
#   'usted',
#   'puede',
#   'elegir',
#   'vibración'],
#  ['número', 'suficiente', 'haga', 'vamos', 'superar', 'conspiración'],
#  ['creemos', 'nuevo', 'sistema'],
#  ['crear', 'nuevo', 'sistema'],
#  ['gaste',
#   'tiempo',
#   'resistiendo',
#   'antiguo',
#   'contrario',
#   'saberlo',
#   'alimenta',
#   'mantiene',
#   'vivo'],
#  ['parte',
#   'serie',
#   'camino',
#   'superar',
#   'conspiración',
#   'escrita',
#   'aquellos',
#   'dan',
#   'cuenta',
#   'actual',
#   'sistema',
#   'completamente',
#   'roto',
#   'disfuncional',
#   'punto',
#   'vista',
#   'funcional',
#   'parte',
#   'superior',
#   'gana',
#   'expensas',
#   'abajo'],
#  ['aunque',
#   'configuración',
#   'actual',
#   'realmente',
#   'sirve',
#   'si',
#   'gastamos',
#   'toda',
#   'energía',
#   'creativa',
#   'sólo',
#   'quejándonos',
#   'mala',
#   'lanzando',
#   'ira',
#   'nunca',
#   'va',
#   'cambiar'],
#  ['centrarnos', 'viene', 'después', 'crear', 'nuevo', 'sistema'],
#  ['crear', 'nuevo', 'sistema', 'hacer', 'viejo', 'obsoleto'],
#  ['último',
#   'gran',
#   'inventor',
#   'teórico',
#   'sistemas',
#   'buckminsterfuller',
#   'dijo'],
#  ['nunca', 'cambie', 'cosas', 'luchando', 'realidad', 'existente'],
#  ['cambiar',
#   'construya',
#   'nuevo',
#   'modelo',
#   'haga',
#   'obsoleto',
#   'modelo',
#   'existente'],
#  ['bucky',
#   'mostró',
#   'profundo',
#   'conocimiento',
#   'hecho',
#   'maestros',
#   'creadores',
#   'cada',
#   'ser',
#   'humano',
#   'planeta',
#   'tendemos',
#   'crear',
#   'manifestar',
#   'atraer',
#   'aquel',
#   'centramos'],
#  ['forma', 'decir', 'proverbio', 'hawaiano'],
#  ['energía', 'fluye', 'va', 'atención'],
#  ['centramos',
#   'especialmente',
#   'si',
#   'intensa',
#   'emoción',
#   'terminará',
#   'creándose',
#   'vida',
#   'incluyendo',
#   'cosas',
#   'usted',
#   'ama',
#   'cosas',
#   'teme'],
#  ['última',
#   'cosa',
#   'queremos',
#   'hacer',
#   'perpetuar',
#   'injusticia',
#   'insensibilidad',
#   'sistema',
#   'actual',
#   'centrando',
#   'demasiado',
#   'atención'],
#  ['gran',
#   'cantidad',
#   'esfuerzo',
#   'parte',
#   'numerosos',
#   'investigadores',
# ...
#   'terrestre',
#   'lhc',
#   'cern'],
#  ['nuevo',
#   'mapeo',
#   'fenómenos',
#   'identifica',
#   'concentración',
#   'relativamente',
#   'pequeña',
#   'rayos',
#   'gamma',
#   'alta',
#   'energía',
#   'enfocados',
#   'centro',
#   'vía',
#   'láctea',
#   'apuntando',
#   'relación',
#   'aceleración',
#   'energía',
#   'varios',
#   'objetos',
#   'clave',
#   'encuentran',
#   'región'],
#  ['algún',
#   'lugar',
#   'dentro',
#   'años',
#   'luz',
#   'centrales',
#   'vía',
#   'láctea',
#   'fuente',
#   'astrofísica',
#   'capaz',
#   'acelerar',
#   'protones',
#   'energías',
#   'aproximadamente',
#   'peta',
#   'electrón',
#   'voltio',
#   'forma',
#   'continua',
#   'menos',
#   'años',
#   'dice',
#   'emmanuel',
#   'moulin',
#   'cea',
#   'saclay'],
#  ['evidencia',
#   'indica',
#   'ahora',
#   'agujero',
#   'negro',
#   'masivo',
#   'centro',
#   'galaxia',
#   'conocido',
#   'sgr'],
#  ['centro',
#   'galaxia',
#   'hogar',
#   'objetos',
#   'capaces',
#   'producir',
#   'rayos',
#   'cósmicos',
#   'alta',
#   'energía',
#   'incluyendo',
#   'particular',
#   'remanente',
#   'supernova',
#   'nebulosa',
#   'viento',
#   'púlsar',
#   'grupo',
#   'compacto',
#   'estrellas',
#   'masivas'],
#  ['supermasivo',
#   'agujero',
#   'negro',
#   'situado',
#   'centro',
#   'galaxia',
#   'llamada',
#   'sgr',
#   'fuente',
#   'plausible',
#   'protones',
#   'pev',
#   'dice',
#   'felix',
#   'aharonian',
#   'mpik',
#   'heidelberg',
#   'dias',
#   'dublín',
#   'añadiendo',
#   'varias',
#   'regiones',
#   'posibles',
#   'aceleración',
#   'pueden',
#   'ser',
#   'consideradas',
#   'vecindad',
#   'inmediata',
#   'agujero',
#   'negro',
#   'lejos',
#   'fracción',
#   'material',
#   'cae',
#   'agujero',
#   'negro',
#   'expulsada',
#   'nuevo',
#   'medio',
#   'ambiente',
#   'iniciando',
#   'modo',
#   'aceleración',
#   'partículas'],
#  ['pensadores',
#   'espiritualistas',
#   'atribuido',
#   'significado',
#   'importante',
#   'radiación',
#   'cósmica',
#   'emana',
#   'centro',
#   'galaxia',
#   'menudo',
#   'atribuyen',
#   'evolución',
#   'conciencia',
#   'humana',
#   'relación',
#   'temporal',
#   'tierra',
#   'fuente',
#   'energías'],
#  ['año',
#   'supuesto',
#   'marcar',
#   'punto',
#   'inflexión',
#   'humanidad',
#   'tierra',
#   'comenzaría',
#   'moverse',
#   'cerca',
#   'centro',
#   'galáctico',
#   'aumentando',
#   'cercanía',
#   'apertura',
#   'radiación',
#   'cósmica',
#   'nutriría',
#   'conciencia',
#   'empujándose',
#   'hacia',
#   'evolución'],
#  ['tierra', 'liderando', 'ascensión', 'humanidad'],
#  ['hizo', 'ascensión', 'fecha'],
#  ['ahora',
#   'posicionada',
#   'tal',
#   'manera',
#   'atrayendo',
#   'información',
#   'directa',
#   'sol',
#   'central'],
#  ['reposicionamiento',
#   'astronómicos',
#   'tan',
#   'perfectamente',
#   'orquestado',
#   'información',
#   'universal',
#   'quedaría',
#   'restringida',
#   'realidad',
#   'lineal',
#   'existe',
#   'actualidad'],
#  ['diciembre', 'repente', 'ganamos', 'acceso', 'puntos', 'universo'],
#  ['abierto',
#   'automáticamente',
#   'mundo',
#   'inteligencia',
#   'información',
#   'presente',
#   'mundos',
#   'principio'],
#  ['abierto', 'puertas', 'potencial', 'infinito'],
#  ['aunque',
#   'exactamente',
#   'científico',
#   'punto',
#   'vista',
#   'obliga',
#   'imaginación',
#   'preguntarse'],
#  ['¿qué', 'centro', 'galaxia'],
#  ['¿de',
#   'dónde',
#   'proviene',
#   'fuerza',
#   'impulsora',
#   'central',
#   'intensa',
#   'radiación'],
#  ['importante', '¿cómo', 'afecta', 'información', 'conciencia', 'humana'],
#  ['tatunca', 'nara', 'marzo'],
#  ['mando',
#   'manaus',
#   'contingente',
#   'brasileño',
#   'jungla',
#   'facilitó',
#   'encuentro'],
#  ['modos', 'enviado', 'documentos', 'lejana', 'ciudad', 'llamada', 'roma'],
#  ['cualquier', 'caso', 'dijeron', 'servidores'],
#  ['agosto',
#   'reportaje',
#   'cinco',
#   'páginas',
#   'mostró',
#   'increíble',
#   'hallazgo'],
#  ['noticia', 'recorrió', 'mundo'],
#  ['vez',
#   'bordo',
#   'nave',
#   'podía',
#   'moverse',
#   'bajo',
#   'agua',
#   'pez',
#   'revelado',
#   'auténtico',
#   'destino'],
#  ['escribió'],
#  ['tiempo',
#   'convierte',
#   'hombre',
#   'temido',
#   'odiado',
#   'raíz',
#   'publicación',
#   'diez',
#   'volúmenes',
#   'centurias',
#   'libros',
#   'cuenta',
#   'resultados',
#   'visiones',
#   'profecías'],
#  ['así'],
#  ['hombres',
#   'cuanto',
#   'dejamos',
#   'ver',
#   'oír',
#   'palpar',
#   'entramos',
#   'mundo',
#   'sombras',
#   'habla',
#   'platón',
#   'diálogos'],
#  ['dios', 'puede', 'ser'],
#  ['acabamos',
#   'decir',
#   'hombre',
#   'infinitos',
#   'peldaños',
#   'escalera',
#   'ninguna',
#   'manera',
#   'alto',
#   'centro',
#   'universo',
#   'empeñe',
#   'pensar',
#   '«',
#   'hijo',
#   'dios',
#   'encarnado',
#   'planeta',
#   'hecho',
#   '»'],
#  ['nivel',
#   'inferior',
#   'podemos',
#   'ver',
#   'cómo',
#   'minerales',
#   'absorbidos',
#   'vegetales',
#   'cómo',
#   'vez',
#   'éstos',
#   'absorbidos',
#   'animales',
#   'formando',
#   'junto',
#   'hombre',
#   'escala',
#   'ininterrumpida',
#   'vida',
#   'atómica',
#   'molecular',
#   'celular',
#   'psíquica',
#   'espiritual'],
#  ['gran', 'diferencia', 'saben', 'existencia', 'sabemos'],
#  ['podría', 'ser', 'explicación', 'muerte', 'aquello', 'vive'],
#  ['lobo', 'come', 'cordero'],
#  ['mujer',
#   'vieja',
#   'dice',
#   'mujer',
#   'vieja',
#   'hombre',
#   'viejo',
#   'dice',
#   'hombre',
#   'viejo'],
#  ['identificación',
#   'embargo',
#   'basa',
#   'exceso',
#   'inscripción',
#   'sargón',
#   'asiria',
#   'cerca',
#   'ac',
#   'afirmó',
#   'reyes',
#   'pagaban',
#   'tributo',
#   'uperi',
#   'rey',
#   'dilmun',
#   'cuya',
#   'morada',
#   'sitúa',
#   'pez',
#   'medio',
#   'mar',
#   'nace',
#   'sol'],
#  ['llegando',
#   'uruk',
#   'manos',
#   'vacías',
#   'gilgamesh',
#   'renuncia',
#   'promesa',
#   'ishtar',
#   'indigna',
#   'envía',
#   'arma',
#   'divina',
#   'destruir',
#   'gilgamesh',
#   'enkidu'],
#  ['dioses',
#   'consejo',
#   'deciden',
#   'alguien',
#   'pagar',
#   'enkidu',
#   'condenado',
#   'morir'],
#  ['enkidu',
#   'enviado',
#   'inframundo',
#   'gilgamesh',
#   'elogia',
#   'amigo',
#   'última',
#   'historia',
#   'gilgamesh',
#   'intenta',
#   'rescatar',
#   'enkidu',
#   'mundo',
#   'inferior',
#   'inframundo'],
#  ['paz', 'prosperidad', 'gracias'],
#  ['sentí', 'momento', 'hacer', 'libro'],
#  ['dijeron'],
#  ['«', 'enviado'],
#  ['recuerda',
#   'proceso',
#   'pasarás',
#   'cierta',
#   'medida',
#   'parte',
#   'historia',
#   'descubrirás',
#   'misma',
#   'luego',
#   'historia',
#   'narrada',
#   'términos',
#   'establezcas'],
#  ['hiciste'],
#  ['dijeron', 'leer', 'libro', 'existía', 'futuro', 'daría', 'vida'],
#  ['sólo', 'debes', 'tener', 'propósito'],
#  ['época',
#   'experiencia',
#   'causó',
#   'pánico',
#   'absoluto',
#   'sentimiento',
#   'conocía',
#   'bien'],
#  ['vaticano', 'punto', 'canonizar'],
#  ['siempre',
#   'convencido',
#   'evidente',
#   'santidad',
#   'eugenio',
#   'pacelli',
#   'prueba',
#   'buena',
#   'fe'],
#  ['¿cómo', 'podría', 'haber', 'traicionado', 'judíos', 'papa', 'tan', 'santo'],
#  ['pedí',
#   'acceso',
#   'documentos',
#   'cruciales',
#   'asegurándoles',
#   'custodios',
#   'lado',
#   'investigado',
#   'libro',
#   'titulado',
#   'ladrón',
#   'noche',
#   'defendido',
#   'vaticano',
#   'cargos',
#   'asesinato',
#   'papa',
#   'juan',
#   'pablo',
#   'pares'],
#  ['dos',
#   'oficiales',
#   'permitieron',
#   'acceder',
#   'material',
#   'secreto',
#   'declaraciones',
#   'bajo',
#   'juramento',
#   'juntaron',
#   'hace',
#   'treinta',
#   'años',
#   'avalar',
#   'proceso',
#   'canonización',
#   'pacelli',
#   'archivo',
#   'secretaría',
#   'vaticano'],
#  ['mediados', 'encontré', 'shock', 'moral'],
#  ['material',
#   'juntado',
#   'apuntaba',
#   'exoneración',
#   'sino',
#   'acusación',
#   'aún',
#   'escandalosa'],
#  ['pacelli',
#   'llegó',
#   'vaticano',
#   'edad',
#   'años',
#   'reclutado',
#   'especializarse',
#   'cuestiones',
#   'internacionales',
#   'derecho',
#   'canónico'],
#  ['colaboró',
#   'superior',
#   'pietro',
#   'gasparri',
#   'reformulación',
#   'código',
#   'derecho',
#   'canónico',
#   'distribuyó',
#   'obispos',
#   'católicos',
#   'mundo'],
#  ['edad',
#   'años',
#   'arzobispo',
#   'pacelli',
#   'partió',
#   'hacia',
#   'munich',
#   'nuncio',
#   'papal',
#   'comenzar',
#   'proceso',
#   'eliminar',
#   'desafíos',
#   'legales',
#   'nueva',
#   'autocracia',
#   'papal',
#   'procurar',
#   'tratado',
#   'papado',
#   'alemania',
#   'reemplazará',
#   'arreglos',
#   'locales',
#   'convirtiera',
#   'modelo',
#   'relaciones',
#   'iglesia',
#   'católica'],
#  ['mayo',
#   'recorrió',
#   'alemania',
#   'destruida',
#   'guerra',
#   'ofreciendo',
#   'caridad',
#   'gente',
#   'todas',
#   'religiones'],
#  ['embargo',
#   'carta',
#   'vaticano',
#   'reveló',
#   'tener',
#   'menos',
#   'amor',
#   'judíos'],
#  ['septiembre',
#   'informó',
#   'gasparri',
#   'cardenal',
#   'secretario',
#   'vaticano',
#   'doctor',
#   'werner',
#   'rabino',
#   'jefe',
#   'munich',
#   'acercado',
#   'nunciatura',
#   'rogar',
#   'favor'],
#  ['fin',
#   'celebrar',
#   'succoth',
#   'judíos',
#   'necesitaban',
#   'hojas',
#   'palmeras',
#   'normalmente',
#   'llegaban',
#   'italia'],
#  ['gobierno',
#   'italiano',
#   'prohibido',
#   'exportación',
#   'vía',
#   'suiza',
#   'unas',
#   'palmeras',
#   'judíos',
#   'comprado',
#   'retenidas'],
#  ['comunidad',
#   'israelita',
#   'continuaba',
#   'pacelli',
#   'busca',
#   'intervención',
#   'papa',
#   'esperanza',
#   'abogue',
#   'favor',
#   'miles',
#   'judíos',
#   'alemanes'],
#  ['pacelli',
#   'dijo',
#   'gasparri',
#   'parecía',
#   'apropiado',
#   'vaticano',
#   'ayudara',
#   'práctica',
#   'culto',
#   'judío'],
#  ['gasparri',
#   'respondió',
#   'confiaba',
#   'completamente',
#   'astucia',
#   'pacelli',
#   'coincidiendo',
#   'apropiado',
#   'ayudar',
#   'rabino',
#   'werner'],
#  ['dieciocho',
#   'meses',
#   'mas',
#   'tarde',
#   'reveló',
#   'antipatía',
#   'judíos',
#   'manera',
#   'abiertamente',
#   'antisemita',
#   'centro',
#   'revuelta',
#   'bolchevique',
#   'munich'],
#  ['carta',
#   'gasparri',
#   'pacelli',
#   'describió',
#   'revolucionarios',
#   'líder',
#   'eugenio',
#   'levien'],
#  ['ejército',
#   'trabajadores',
#   'corría',
#   'lado',
#   'dando',
#   'órdenes',
#   'medio',
#   'pandilla',
#   'mujeres',
#   'jóvenes',
#   'dudosa',
#   'apariencia',
#   'judías',
#   'demás',
#   'daba',
#   'vueltas',
#   'salas',
#   'sonrisas',
#   'provocativas',
#   'degradantes',
#   'sugestivas'],
#  ['jefa',
#   'pandilla',
#   'mujeres',
#   'amante',
#   'levien',
#   'joven',
#   'mujer',
#   'rusa',
#   'judía',
#   'divorciada'],
#  ['levien', 'hombre', 'joven', 'años', 'ruso', 'judío'],
#  ['pálido',
#   'sucio',
#   'ojos',
#   'vacíos',
#   'voz',
#   'ronca',
#   'vulgar',
#   'repulsivo',
#   'cara',
#   'vez',
#   'inteligente',
#   'taimada'],
#  ['hitler',
#   'logrado',
#   'primer',
#   'gran',
#   'triunfo',
#   'elecciones',
#   'quería',
#   'trato',
#   'vaticano',
#   'convencido',
#   'movimiento',
#   'sólo',
#   'podía',
#   'tener',
#   'éxito',
#   'si',
#   'eliminaba',
#   'catolicismo',
#   'político',
#   'redes',
#   'democráticas'],
#  ['luego',
#   'ascenso',
#   'poder',
#   'enero',
#   'hitler',
#   'hizo',
#   'prioridad',
#   'negociación',
#   'pacelli'],
#  ['concordato',
#   'reich',
#   'garantizó',
#   'pacelli',
#   'derecho',
#   'imponer',
#   'nuevo',
#   'código',
#   'leyes',
#   'canónicas',
#   'católicos',
#   'alemania'],
#  ['cambio',
#   'pacelli',
#   'colaboró',
#   'retiro',
#   'católicos',
#   'actividad',
#   'política',
#   'social'],
#  ['luego',
#   'hitler',
#   'insistió',
#   'disolución',
#   'voluntaria',
#   'partido',
#   'central',
#   'católico',
#   'alemán'],
#  ['judíos',
#   'primeras',
#   'víctimas',
#   'concordato',
#   'luego',
#   'firma',
#   'julio',
#   'hitler',
#   'dijo',
#   'gabinete',
#   'tratado',
#   'creado',
#   'atmósfera',
#   'confianza',
#   'especialmente',
#   'significativa',
#   'lucha',
#   'urgente',
#   'judaísmo',
#   'internacional'],
#  ['aseguraba',
#   'iglesia',
#   'católica',
#   'dado',
#   'bendición',
#   'pública',
#   'país',
#   'afuera',
#   'nacional',
#   'socialismo',
#   'incluida',
#   'posición',
#   'antisemita'],
#  ['enero',
#   'tres',
#   'cardenales',
#   'dos',
#   'obispos',
#   'alemanes',
#   'viajaron',
#   'vaticano',
#   'pedir',
#   'vigorosa',
#   'protesta',
#   'persecución',
#   'nazi',
#   'iglesia',
#   'católica',
#   'suprimido',
#   'todas',
#   'formas',
#   'actividad',
#   'excepción',
#   'servicios',
#   'religiosos'],
#  ['verano',
#   'mientras',
#   'agonizaba',
#   'pio',
#   'xii',
#   'preocupó',
#   'antisemitismo',
#   'europa',
#   'encargó',
#   'redacción',
#   'encíclica',
#   'dedicada',
#   'tema'],
#  ['texto', 'nunca', 'vió', 'luz', 'día', 'descubrió', 'hace'],
#  ['escribieron',
#   'tres',
#   'jesuitas',
#   'presumiblemente',
#   'pacelli',
#   'cargo',
#   'proyecto'],
#  ['iba',
#   'llamar',
#   'humani',
#   'generis',
#   'unitas',
#   'unión',
#   'raza',
#   'humana',
#   'pesar',
#   'buenas',
#   'intenciones',
#   'lleno',
#   'antisemitismo',
#   'pacelli',
#   'mostrado',
#   'primer',
#   'estadía',
#   'alemania'],
#  ['judíos',
#   'dice',
#   'texto',
#   'responsables',
#   'destino',
#   'dios',
#   'elegido',
#   'negaron',
#   'mataron',
#   'cristo'],
#  ['cegados',
#   'sueño',
#   'triunfo',
#   'mundial',
#   'éxito',
#   'materialista',
#   'merecían',
#   'ruina',
#   'material',
#   'espiritual',
#   'echado',
#   'mismos'],
#  ['documento',
#   'advierte',
#   'defender',
#   'judíos',
#   'exigen',
#   'principios',
#   'humanidad',
#   'cristianos',
#   'podría',
#   'conllevar',
#   'riesgo',
#   'inaceptable',
#   'caer',
#   'trampa',
#   'política',
#   'secular'],
#  ['pacelli',
#   'conoció',
#   'planes',
#   'nazis',
#   'exterminar',
#   'judíos',
#   'europa',
#   'enero'],
#  ['deportaciones', 'campos', 'exterminio', 'comenzado', 'diciembre'],
#  ['largo',
#   'pacelli',
#   'recibió',
#   'información',
#   'confiable',
#   'detalles',
#   'solución',
#   'final',
#   'provista',
#   'británicos',
#   'franceses',
#   'norteamericanos',
#   'vaticano'],
#  ['marzo',
#   'representantes',
#   'organizaciones',
#   'judías',
#   'reunidos',
#   'suiza',
#   'enviaron',
#   'memorando',
#   'través',
#   'nuncio',
#   'papal',
#   'berna',
#   'detallaban',
#   'violentas',
#   'medidas',
#   'antisemitas',
#   'alemania',
#   'territorios',
#   'aliados',
#   'zonas',
#   'conquistadas'],
#  ['memo', 'excluido', 'documentos', 'época', 'guerra', 'vaticano', 'publicó'],
#  ['septiembre',
#   'presidente',
#   'norteamericano',
#   'franklin',
#   'roosevelt',
#   'envió',
#   'representante',
#   'personal',
#   'mylon',
#   'taylor',
#   'pidiera',
#   'pacelli',
#   'declaración',
#   'exterminio',
#   'judíos'],
#  ['pacelli', 'negó', 'hablar', 'debía', 'elevarse', 'partes', 'beligerantes'],
#  ['diciembre', 'finalmente', 'pacelli', 'habló'],
#  ['aquellos',
#   'cientos',
#   'miles',
#   'culpa',
#   'propia',
#   'veces',
#   'sólo',
#   'nacionalidad',
#   'raza',
#   'reciben',
#   'marca',
#   'muerte',
#   'extinción',
#   'gradual'],
#  ['denuncia', 'pública', 'mas', 'fuerte', 'solución', 'final'],
#  ['nueva', 'evidencia', 'recopilé', 'muestra'],
#  ['asombrosa',
#   'antipatía',
#   'pacelli',
#   'judíos',
#   'venía',
#   'contradice',
#   'omisiones',
#   'hechas',
#   'buena',
#   'fe',
#   'amaba',
#   'judíos',
#   'respetaba',
#   'religión'],
#  ['pacelli',
#   'reconoció',
#   'tercer',
#   'reich',
#   'políticas',
#   'antisemitas',
#   'asuntos',
#   'internos',
#   'alemania'],
#  ['concordato',
#   'hitler',
#   'vaticano',
#   'creó',
#   'clima',
#   'ideal',
#   'persecución',
#   'judíos'],
#  ['pacelli',
#   'avaló',
#   'protesta',
#   'obispos',
#   'católicos',
#   'alemanes',
#   'antisemitismo'],
#  ['pacelli',
#   'intentó',
#   'mitigar',
#   'efecto',
#   'encíclicas',
#   'pío',
#   'xii',
#   'darle',
#   'garantías',
#   'diplomáticas',
#   'privadas',
#   'berlín',
#   'pesar',
#   'conocer',
#   'abierta',
#   'persecución',
#   'judíos'],
#  ['pacelli',
#   'convencido',
#   'judíos',
#   'procurado',
#   'suerte',
#   'intervenir',
#   'favor',
#   'sólo',
#   'podía',
#   'llevar',
#   'iglesia',
#   'hacia',
#   'alianzas',
#   'fuerzas',
#   'hostiles',
#   'catolicismo'],
#  ['veía', 'fondo', 'agujero', 'negro'],
#  ['absolutamente', 'vivo', 'vivo', 'potencia', 'parecía', 'infinita'],
#  ['vida',
#   'incalculable',
#   'tal',
#   'punto',
#   'único',
#   'puede',
#   'decir',
#   'infinita',
#   'tan',
#   'llena',
#   'imágenes'],
#  ['intensidad', 'potencia', 'fuerza', 'paz', 'paz', 'eternidad'],
#  [],
#  ['tres', 'veces', 'verdaderamente', 'impresión', 'punto', 'dislocara'],
#  ['nuevo', 'trama', 'vuelve', 'cerrar'],
#  ['si',
#   'mueve',
#   'espacio',
#   'vez',
#   'allá',
#   'inmovilidad',
#   'allá',
#   'movimiento',
#   'rapidez',
#   'absolutamente',
#   'imperceptible'],
#  ['parece', 'ser', 'todopoderoso'],
#  ['constante'],
#  ['constante', 'aquello'],
#  ['luego',
#   'caso',
#   'semejante',
#   'consciencia',
#   'semejante',
#   'entonces',
#   'ahí',
#   'escapa',
#   'armonía',
#   'desaparece',
#   '¿por',
#   'razón'],
#  ['¿y', 'escapa'],
#  ['embargo', 'mismo', 'mundo'],
#  ['misma', 'cosa'],
#  ['¿cuál', 'mecanismo'],
#  ['cosas', 'tan', 'reales', 'tan', 'precisas', 'aquí'],
#  ['sé', 'cuál', 'diferencia'],
#  ['hecho',
#   'capital',
#   'lado',
#   'trama',
#   'mente',
#   'física',
#   'leyes',
#   'físicas',
#   'fisiológicas',
#   'mismas',
#   'lado'],
#  ['¡no', 'claro'],
#  [],
#  ...]

# %%
model = Word2Vec(sentences_corpus['text'], vector_size=100, window=5, min_count=2, workers=6, sg=1)

# Podemos guardar el modelo para uso futuro
model.save("word2vec.model")

# %%
model.wv['rey']
# Out:
# array([-4.7621585e-02,  3.9839599e-01,  4.8014563e-01, -2.4782281e-02,
#        -3.2940465e-01, -1.3604504e-01, -1.5344818e-01,  4.8451424e-01,
#        -4.3801153e-01, -5.5046093e-01, -6.9141823e-01, -2.0335713e-01,
#        -4.6941120e-04, -8.5356809e-02, -2.7640197e-01,  1.6081220e-02,
#        -3.9780596e-01, -6.6929233e-01,  3.8406175e-02, -1.7596897e-01,
#         1.6429284e-01,  9.9311328e-01, -2.2006106e-02, -6.1447084e-01,
#         5.5180812e-01,  3.7671229e-01, -1.8067293e-01, -1.7508706e-01,
#        -2.4473664e-01, -2.4074218e-01, -2.5335833e-01,  4.3585524e-01,
#         4.0107259e-01, -1.8833454e-01, -2.3448601e-01,  5.8438838e-01,
#         4.2057693e-02, -2.2725542e-01, -3.8843066e-01, -6.1544228e-01,
#        -3.4959993e-01,  1.1861115e-01,  5.9657562e-01, -7.4290454e-01,
#         2.5636178e-01,  5.9737229e-01, -1.2362590e+00,  2.5330812e-01,
#         4.0826678e-01,  6.3538617e-01, -4.0549290e-01, -6.5254933e-01,
#        -7.4612752e-02, -1.6330540e-01,  4.1698360e-01, -3.1338912e-01,
#        -1.9704315e-01,  2.1487592e-02, -5.0156009e-01,  4.1434452e-01,
#        -3.3822355e-01,  1.8686934e-01,  5.2831727e-01, -5.0674725e-01,
#         6.4800036e-01,  8.4615868e-01, -4.3209261e-01, -9.3328893e-02,
#        -2.2537960e-02, -2.3461930e-01,  2.4993098e-01,  9.0366560e-01,
#        -3.5204762e-01, -1.2444249e-01,  7.8903252e-01,  5.4520935e-02,
#        -4.6262056e-01, -8.1521377e-02, -4.5228082e-01,  3.4557256e-01,
#         1.2059439e-01, -4.6496505e-01,  1.2246744e-01,  1.3757612e-01,
#         2.5235742e-01,  3.7702907e-02, -5.0811636e-01, -4.0752888e-01,
#         1.5363203e-01,  3.4431782e-01,  3.6873189e-01, -3.7128691e-02,
#        -1.2060407e-01, -6.0242128e-01,  4.6851796e-01,  7.8549296e-01,
#         8.1435490e-01,  2.5942525e-01, -3.1117961e-01,  2.1813872e-01],
#       dtype=float32)

# %%
model.wv.most_similar('television', topn=5)
# Out:
# [('gsm', 0.8683694005012512),
#  ('entertainment', 0.8665755391120911),
#  ('supren', 0.8458159565925598),
#  ('player', 0.8333703279495239),
#  ('broadcaster', 0.833152174949646)]

# %%
word_vectors = model.wv
vectors = word_vectors.vectors
words = word_vectors.index_to_key

# %% [markdown]
# ### Almacenamiento de embeddings

# %%
df_vectors = pd.DataFrame(vectors)
df_vectors.to_csv('embeddings.tsv', sep='\t', index=False)

# %%
df_words = pd.DataFrame(words)
df_words.to_csv('words.tsv', sep='\t', index=False)
